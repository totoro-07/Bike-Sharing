# %% [markdown]
# # Proyek Analisis Data: Bike Sharing  Dataset
# - **Nama:** Ahmad Radesta
# - **Email:** ahmadradesta95@gmail.com
# - **ID Dicoding:** MC189D5Y0819

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# 1.   Bagaimana *trend* penggunaan *bike sharing* setiap tahun?
# 2.   Bagaimana pengaruh kondisi cuaca terhadap persentase jumlah pengguna  *bike sharing*?
# 3.   Bagaimana pengaruh musim terhadap persentase jumlah pengguna *bike sharing*?
# 4.   Pada jam berapa jumlah peminjaman sepeda paling tinggi?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("lakshmi25npathi/bike-sharing-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 286k/286k [00:00<00:00, 901kB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/lakshmi25npathi/bike-sharing-dataset/versions/1

# %%
days_df = pd.read_csv("/root/.cache/kagglehub/datasets/lakshmi25npathi/bike-sharing-dataset/versions/1/day.csv")
days_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
hours_df = pd.read_csv("/root/.cache/kagglehub/datasets/lakshmi25npathi/bike-sharing-dataset/versions/1/hour.csv")
hours_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# **Insight:**
#
# 1. Dataset Terbagi dalam Dua Bagian
#
#   *   days_df: Data penyewaan sepeda berdasarkan hari (day.csv), berisi informasi harian.
#   *   hours_df: Data penyewaan sepeda berdasarkan jam (hour.csv), berisi informasi per jam.
#
#
#
# 2. Fitur-Fitur Penting dalam Dataset
#
#   *   Tanggal (dteday): Mencatat waktu peminjaman sepeda.
#   *   Musim (season): Dikodekan (1 = musim semi, 2 = musim panas, 3 = musim gugur, 4 = musim dingin).
#   *   Cuaca (weathersit): Kategori cuaca yang mempengaruhi penggunaan sepeda.
#   Suhu (temp) & Suhu Terasa (atemp): Faktor lingkungan yang bisa berdampak pada jumlah pengguna.
#   *   Kelembaban (hum) & Kecepatan Angin (windspeed): Bisa mempengaruhi kenyamanan bersepeda.
#   *   Jumlah Pengguna (casual, registered, cnt):
#   casual: Pengguna tidak terdaftar.
#   registered: Pengguna terdaftar.
#   cnt: Total jumlah pengguna.
#
# 3. Perbedaan Data Harian dan Per Jam
#
#   *   days_df memberikan gambaran tren jangka panjang (musiman, mingguan, dll.).
#   hours_df memungkinkan analisis lebih detail terhadap pola penggunaan dalam sehari.
#
# 4. Tren Awal yang Terlihat
#
#   *   Jumlah total pengguna (cnt) harian bervariasi, berkisar antara 800 hingga 1600 di contoh data.
#   Sebagian besar pengguna adalah registered users, bukan casual users.
#   Pada data per jam, jumlah pengguna lebih rendah di jam-jam awal hari (subuh).

# %% [markdown]
# ### Assessing Data

# %%
days_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
days_df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %%
hours_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
hours_df.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %% [markdown]
# **Insight:**
# 1. Analisis Data Harian (days_df)
#
#   *   Jumlah Total Data: 731 entri, mencakup sekitar 2 tahun data.
#   *   Distribusi Pengguna:
#     *   Rata-rata total peminjaman (cnt): ~4504 sepeda/hari.
#     *   Pengguna terdaftar (registered) jauh lebih banyak dibandingkan pengguna kasual (casual).
#     *   Minimumnya (cnt): 22 sepeda, kemungkinan hari dengan cuaca buruk atau libur besar.
#   *   Cuaca & Lingkungan:
#     *   Rata-rata suhu (temp): 0.49 (nilai dinormalisasi).
#     *   Kelembaban (hum) berkisar antara 0.0 hingga 0.972.
#     *   Kecepatan angin (windspeed) memiliki nilai maksimum 0.507.
#
# 2. Analisis Data Per Jam (hours_df)
#
#   *   Jumlah Total Data: 17.729 entri, mencakup data penggunaan per jam.
#   *   Distribusi Pengguna:
#     *   Rata-rata total peminjaman (cnt): ~189 per jam.
#     *   Pengguna terdaftar (registered) lebih dominan dibandingkan pengguna kasual (casual).
#     *   Minimum peminjaman (cnt): 1 sepeda/jam, mungkin pada dini hari atau kondisi cuaca buruk.
#     * Maksimum peminjaman (cnt): 977 sepeda/jam, kemungkinan jam sibuk.
#   *   Pola Penggunaan:
#     *   Hari kerja (workingday) memiliki rata-rata 0.68, menunjukkan lebih banyak data pada hari kerja dibanding hari libur.
#     *   Jam (hr) dapat dianalisis lebih lanjut untuk melihat jam-jam sibuk dan sepi.

# %% [markdown]
# ### Cleaning Data

# %%
days_df["dteday"] = pd.to_datetime(days_df["dteday"])
hours_df['dteday'] = pd.to_datetime(hours_df['dteday'])

# %%
days_df.rename(columns={
    "dteday": "date",
    "yr": "year",
    "mnth": "month",
    "cnt": "total_count"
}, inplace=True)

# %%
hours_df.rename(columns={
    "dteday": "date",
    "yr": "year",
    "mnth": "month",
    "hr": "hour",
    "cnt": "total_count"
}, inplace=True)

# %%
days_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   instant      731 non-null    int64
#  1   date         731 non-null    datetime64[ns]
#  2   season       731 non-null    int64
#  3   year         731 non-null    int64
#  4   month        731 non-null    int64
#  5   holiday      731 non-null    int64
#  6   weekday      731 non-null    int64
#  7   workingday   731 non-null    int64
#  8   weathersit   731 non-null    int64
#  9   temp         731 non-null    float64
#  10  atemp        731 non-null    float64
#  11  hum          731 non-null    float64
#  12  windspeed    731 non-null    float64
#  13  casual       731 non-null    int64
#  14  registered   731 non-null    int64
#  15  total_count  731 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(11)
# memory usage: 91.5 KB

# %%
hours_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   instant      17379 non-null  int64
#  1   date         17379 non-null  datetime64[ns]
#  2   season       17379 non-null  int64
#  3   year         17379 non-null  int64
#  4   month        17379 non-null  int64
#  5   hour         17379 non-null  int64
#  6   holiday      17379 non-null  int64
#  7   weekday      17379 non-null  int64
#  8   workingday   17379 non-null  int64
#  9   weathersit   17379 non-null  int64
#  10  temp         17379 non-null  float64
#  11  atemp        17379 non-null  float64
#  12  hum          17379 non-null  float64
#  13  windspeed    17379 non-null  float64
#  14  casual       17379 non-null  int64
#  15  registered   17379 non-null  int64
#  16  total_count  17379 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(12)
# ...

# %% [markdown]
# **Insight:**
# 1.  Konversi Kolom dteday ke Format Datetime
#   *   Kini kolom tanggal (dteday) diubah menjadi tipe data datetime64[ns] pada kedua dataset (days_df dan hours_df).
#   *   Ini akan memudahkan analisis berbasis waktu, seperti tren harian, musiman, atau per jam.
# 2. Rename Kolom untuk Kejelasan
#   *   Kolom dteday → date, yr → year, mnth → month, hr → hour, cnt → total_count.
#   *   Pergantian nama ini membuat dataset lebih intuitif dan mudah dipahami.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %%
days_df.describe(include="all")
# Out:
#           instant                 date      season        year       month  \
# count  731.000000                  731  731.000000  731.000000  731.000000
# mean   366.000000  2012-01-01 00:00:00    2.496580    0.500684    6.519836
# min      1.000000  2011-01-01 00:00:00    1.000000    0.000000    1.000000
# 25%    183.500000  2011-07-02 12:00:00    2.000000    0.000000    4.000000
# 50%    366.000000  2012-01-01 00:00:00    3.000000    1.000000    7.000000
# 75%    548.500000  2012-07-01 12:00:00    3.000000    1.000000   10.000000
# max    731.000000  2012-12-31 00:00:00    4.000000    1.000000   12.000000
# std    211.165812                  NaN    1.110807    0.500342    3.451913
#
#           holiday     weekday  workingday  weathersit        temp       atemp  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.028728    2.997264    0.683995    1.395349    0.495385    0.474354
# ...

# %%
days_df["year"] = days_df["year"].replace({0: 2011, 1: 2012})
days_df.groupby(by='year').total_count.sum()
# Out:
# year
# 2011    1243103
# 2012    2049576
# Name: total_count, dtype: int64

# %%
days_df["season"] = days_df["season"].replace({
    1: "Spring",
    2: "Summer",
    3: "Fall",
    4: "Winter"
})

# %%
days_df.groupby(by='season').agg({
    "casual": ["max", "min", "mean", "sum"],
    "registered": ["max", "min", "mean", "sum"],
    "total_count": ["max", "min", "mean", "sum"]
})
# Out:
#        casual                           registered                            \
#           max  min         mean     sum        max  min         mean     sum
# season
# Fall     3160  118  1202.611702  226091       6917  889  4441.691489  835038
# Spring   3155    9   334.928177   60622       5315  416  2269.204420  410726
# Summer   3410  120  1106.097826  203522       6456  674  3886.233696  715067
# Winter   3031    2   729.112360  129782       6946   20  3999.050562  711831
#
#        total_count
#                max   min         mean      sum
# season
# Fall          8714  1115  5644.303191  1061129
# Spring        7836   431  2604.132597   471348
# Summer        8362   795  4992.331522   918589
# Winter        8555    22  4728.162921   841613

# %%
days_df["weekday"] = days_df["weekday"].replace({
    0: "Sunday",
    1: "Monday",
    2: "Tuesday",
    3: "Wednesday",
    4: "Thursday",
    5: "Friday",
    6: "Saturday"
})

# %%
days_df.groupby("weekday").agg({
    "casual": ["max", "min", "mean", "sum"],
    "registered": ["max", "min", "mean", "sum"],
     'total_count':['max','min','mean']
}).reindex(["Sunday","Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday"])
# Out:
#           casual                          registered                     \
#              max min         mean     sum        max   min         mean
# weekday
# Sunday      3283  54  1338.295238  140521       5657   451  2890.533333
# Monday      3065   2   674.133333   70784       6435    20  3663.990476
# Tuesday     1348   9   556.182692   57843       6697   573  3954.480769
# Wednesday   2562   9   551.144231   57319       6946   432  3997.394231
# Thursday    1405  15   590.961538   61460       6781   416  4076.298077
# Friday      2469  38   752.288462   78238       6917  1129  3938.000000
# Saturday    3410  57  1465.257143  153852       5966   570  3085.285714
#
#                   total_count
#               sum         max   min         mean
# weekday
# Sunday     303506        8227   605  4228.828571
# Monday     384719        7525    22  4338.123810
# Tuesday    411266        7767   683  4510.663462
# Wednesday  415729        8173   441  4548.538462
# ...

# %%
hours_df.describe(include="all")
# Out:
#           instant                           date        season          year  \
# count  17379.0000                          17379  17379.000000  17379.000000
# mean    8690.0000  2012-01-02 04:08:34.552045568      2.501640      0.502561
# min        1.0000            2011-01-01 00:00:00      1.000000      0.000000
# 25%     4345.5000            2011-07-04 00:00:00      2.000000      0.000000
# 50%     8690.0000            2012-01-02 00:00:00      3.000000      1.000000
# 75%    13034.5000            2012-07-02 00:00:00      3.000000      1.000000
# max    17379.0000            2012-12-31 00:00:00      4.000000      1.000000
# std     5017.0295                            NaN      1.106918      0.500008
#
#               month          hour       holiday       weekday    workingday  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       6.537775     11.546752      0.028770      3.003683      0.682721
# ...

# %%
hours_df.groupby("hour")["total_count"].mean().sort_values(ascending=False)
# Out:
# hour
# 17    461.452055
# 18    425.510989
# 8     359.011004
# 16    311.983562
# 19    311.523352
# 13    253.661180
# 12    253.315934
# 15    251.233196
# 14    240.949246
# 20    226.030220
# 9     219.309491
# 7     212.064649
# 11    208.143054
# 10    173.668501
# 21    172.314560
# 22    131.335165
# 23     87.831044
# 6      76.044138
# 0      53.898072
# 1      33.375691
# 2      22.869930
# 5      19.889819
# 3      11.727403
# 4       6.352941
# Name: total_count, dtype: float64

# %%
hours_df["workingday"] = hours_df["workingday"].map({0: "Weekend", 1: "Weekday"})
hours_df.groupby("workingday")["total_count"].mean()
# Out:
# workingday
# Weekday    193.207754
# Weekend    181.405332
# Name: total_count, dtype: float64

# %% [markdown]
# **Insight:**
# 1. Jumlah Pengguna per Tahun
#   *  Pada tahun 2011, total jumlah pengguna adalah 1.24 juta.
#   *  Pada tahun 2012, meningkat menjadi 2.05 juta.
#   *  Insight: Terjadi peningkatan signifikan dalam jumlah pengguna dari 2011 ke 2012, yang bisa disebabkan oleh faktor seperti peningkatan popularitas layanan atau kondisi cuaca yang lebih baik.
# 2. Pengaruh Musim terhadap Jumlah Pengguna
#   *  Musim dengan jumlah pengguna tertinggi: Musim gugur (fall) dengan total 1.06 juta pengguna.
#   * Musim dengan jumlah pengguna terendah: Musim dingin (winter) dengan total 841 ribu pengguna.
#   * Insight: Musim gugur adalah periode paling ramai, sedangkan musim dingin memiliki jumlah pengguna yang lebih rendah, mungkin karena cuaca dingin mengurangi keinginan untuk bersepeda.
# 3. Distribusi Pengguna Berdasarkan Hari dalam Seminggu
#   * Hari kerja (weekday) memiliki rata-rata jumlah pengguna yang lebih tinggi dibandingkan akhir pekan.
#   * Insight: Ini menunjukkan bahwa layanan ini lebih sering digunakan untuk keperluan kerja atau aktivitas rutin dibandingkan dengan aktivitas santai di akhir pekan.
# 4. Jumlah Pengguna Berdasarkan Jam dalam Sehari
#   * Jam dengan jumlah pengguna tertinggi: Pukul 17:00 (sore) dan 18:00 (sore).
#   * Jam dengan jumlah pengguna terendah: Pukul 4:00 pagi.
#   * Insight: Lonjakan pengguna terjadi pada jam pulang kerja (rush hour), yang menegaskan bahwa banyak orang menggunakan layanan ini sebagai transportasi utama pulang dari kantor.
# 5. Pengaruh Hari Kerja vs Akhir Pekan
#   * Rata-rata jumlah pengguna pada hari kerja lebih tinggi (193 pengguna per jam) dibandingkan dengan akhir pekan (181 pengguna per jam).
#   * Insight: Layanan ini lebih banyak digunakan pada hari kerja, mendukung hipotesis bahwa penggunaannya lebih banyak untuk keperluan transportasi daripada rekreasi.

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Bagaimana trend penggunaan bike sharing setiap tahun?

# %%
hours_df['bln'] = hours_df['date'].dt.strftime('%b')
hours_df['bln'] = pd.Categorical(hours_df['bln'],
                               ordered=True,
                               categories=['Jan',
                                           'Feb',
                                           'Mar',
                                           'Apr',
                                           'May',
                                           'Jun',
                                           'Jul',
                                           'Aug',
                                           'Sep',
                                           'Oct',
                                           'Nov',
                                           'Dec'])

bike = hours_df[['year', 'total_count', 'bln']]
bike2011 = bike.loc[bike['year'] == 0]
bike2011 = bike2011[['bln', 'total_count']].groupby('bln', observed=False).sum().reset_index()

bike2012 = bike.loc[bike['year'] == 1]
bike2012 = bike2012[['bln', 'total_count']].groupby('bln', observed=False).sum().reset_index()


plt.figure(figsize = (10,5))

plt.plot(
    bike2011['bln'],
    bike2011['total_count'],
    label='2011',
    marker=".",
    linewidth=2,
)

plt.plot(
    bike2012['bln'],
    bike2012['total_count'],
    label='2012',
    marker=".",
    linewidth=2,
)

plt.xlabel('Bulan')
plt.ylabel('Jumlah pengguna')
plt.title('Trend Penggunaan Bike Sharing')
plt.legend()
plt.show()

# %% [markdown]
# ### Pertanyaan 2: Bagaimana pengaruh kondisi cuaca terhadap persentase jumlah pengguna bike sharing?

# %%
def cuaca(x):
  if x == 1:
    return 'Clear'
  elif x == 2:
    return 'Cloudy'
  elif x == 3:
    return 'Light Snow'
  else:
    return 'Heavy Rain'

hours_df['cuaca'] = hours_df['weathersit'].apply(cuaca)

weather = hours_df[['cuaca', 'total_count']].groupby('cuaca').sum().sort_values(by='total_count', ascending=False).reset_index()

plt.figure(figsize = (10, 5))
plt.title("Persentase Pengguna Bike Sharing Berdasarkan Keadaan Cuaca")
colors = ['#3498db', '#2ecc71', '#f1c40f', '#e74c3c']

plt.pie(
    weather['total_count'],
    labels=weather['cuaca'],
    autopct= '%1.1f%%',
    colors = colors,
    wedgeprops={'edgecolor': 'white'}
)

plt.show()

# %% [markdown]
# ### Pertanyaan 3:  Bagaimana pengaruh musim terhadap persentase jumlah pengguna *bike sharing*?

# %%
def musim(x):
  if x == 1:
    return 'Spring'
  elif x == 2:
    return 'Summer'
  elif x == 3:
    return 'Fall'
  else:
    return 'Winter'

hours_df['musim'] = hours_df['season'].apply(musim)
season = hours_df[['musim', 'total_count']].groupby('musim').sum().sort_values(by='total_count', ascending=False).reset_index()

colors = ['#3498db', '#2ecc71', '#f1c40f', '#e74c3c']
plt.title("Persentase Pengguna Bike Sharing Berdasarkan Musim", fontsize=14)

plt.pie(
    season['total_count'],
    labels=season['musim'],
    autopct='%1.1f%%',
    colors=colors,
    wedgeprops={'edgecolor': 'white'}
)

plt.show()

# %% [markdown]
# ### Pertanyaan 4: Pada jam berapa jumlah peminjaman sepeda paling tinggi?

# %%
hours_df['musim'] = hours_df['season'].apply(musim)

user_hour = hours_df[['season', 'hour', 'total_count']]
user_hour = user_hour[['hour', 'season', 'total_count']].groupby('hour').sum().reset_index()

fig = plt.figure(figsize=(10, 5))

plt.figure(figsize=(10, 5))

plt.plot(
    user_hour['hour'],
    user_hour['total_count'],
    marker="o",
    linestyle="-",
    linewidth=2,
    color="#FF5733",
)

plt.ylabel('Jumlah Pengguna', fontsize=12)
plt.xlabel('Jam', fontsize=12)
plt.title('Tingkat Penggunaan Bike Sharing Berdasarkan Waktu', fontsize=14)

plt.xticks(ticks=range(0, 24), labels=range(0, 24))  # Menjaga keterbacaan sumbu x

plt.show()

# %% [markdown]
# **Insight:**
# 1. Trend Penggunaan Bike Sharing Setiap Tahun
#   * Penggunaan bike sharing meningkat pada tahun 2012 dibandingkan dengan 2011.
#   * Pola penggunaan menunjukkan tren musiman, dengan peningkatan dari awal tahun hingga puncaknya di musim panas (Juni-Agustus), lalu menurun menjelang akhir tahun.
#   * Faktor cuaca dan musim kemungkinan besar mempengaruhi tingkat penggunaan ini.
# 2. Pengaruh Kondisi Cuaca terhadap Persentase Pengguna
#   * Mayoritas pengguna bike sharing memilih untuk bersepeda dalam kondisi cuaca cerah (71%).
#   * Cuaca mendung (24.2%) juga masih cukup banyak digunakan, tetapi jumlahnya jauh lebih rendah dibandingkan cuaca cerah.
#   * Kondisi hujan lebat atau salju ringan memiliki dampak negatif terhadap jumlah pengguna, dengan persentase yang sangat kecil (<5%).
#   * Ini menunjukkan bahwa kondisi cuaca yang lebih baik cenderung meningkatkan penggunaan bike sharing.
# 3. Pengaruh Musim terhadap Jumlah Pengguna
#   * Penggunaan bike sharing paling tinggi terjadi pada musim gugur (32.2%) dan musim panas (27.9%).
#   * Musim dingin memiliki tingkat penggunaan yang lebih rendah (25.6%), sedangkan musim semi memiliki penggunaan terendah (14.3%).
#   * Ini bisa disebabkan oleh faktor cuaca yang lebih nyaman untuk bersepeda di musim gugur dan musim panas.
# 4. Jam dengan Jumlah Pemakaian Tertinggi
#   * Pemakaian bike sharing meningkat secara signifikan pada jam sibuk, yaitu sekitar pukul 7-9 pagi dan 5-7 sore.
#   * Peningkatan ini menunjukkan bahwa mayoritas pengguna kemungkinan besar adalah pekerja atau pelajar yang menggunakan bike sharing sebagai moda transportasi utama atau tambahan.
#   * Selama tengah malam hingga dini hari (00:00 - 06:00), penggunaan sangat rendah.
#   * Pola ini menunjukkan bahwa bike sharing lebih banyak digunakan untuk aktivitas sehari-hari seperti pergi dan pulang kerja/sekolah dibandingkan penggunaan rekreasional.

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# ## Conclusion
# # 1. Bagaimana trend penggunaan bike sharing setiap tahun?
#
#
# *   Penggunaan bike-sharing meningkat drastis dari 2011 ke 2012, dengan lonjakan terbesar pada Maret-Mei 2011 dan Februari 2012, kemungkinan dipengaruhi oleh acara musiman. Sebaliknya, terjadi penurunan pengguna pada Oktober-Desember, kemungkinan akibat musim dingin
#
#
# #2. Bagaimana pengaruh kondisi cuaca terhadap persentase jumlah pengguna bike sharing?
# *   Mayoritas pengguna bike-sharing lebih memilih menggunakan sepeda saat cuaca cerah (71% penggunaan terjadi saat cuaca "Clear"). Saat cuaca mendung (Cloudy, 24.2%), penggunaan sedikit menurun, tetapi masih cukup tinggi. Penggunaan sepeda turun drastis dalam kondisi hujan deras atau salju, hampir 0% pengguna menggunakan sepeda dalam kondisi "Heavy Rain", dan hanya sekitar 4.8% dalam kondisi "Light Snow".
#
# #3. Bagaimana pengaruh musim terhadap persentase jumlah pengguna bike sharing?
# *   Penggunaan bike-sharing bervariasi tergantung musim. Musim gugur (Fall) memiliki jumlah pengguna tertinggi (32.2%), diikuti oleh musim panas (Summer, 27.9%) dan musim dingin (Winter, 25.6%). Penggunaan sepeda paling rendah terjadi pada musim semi (Spring, 14.3%), yang kemungkinan disebabkan oleh cuaca yang kurang mendukung atau curah hujan yang lebih tinggi.
#
# #4. Pada jam berapa jumlah peminjaman sepeda paling tinggi?
# *  Peminjaman sepeda mencapai puncaknya pada pukul 08.00 dan 17.00-18.00, yang mencerminkan pola perjalanan komuter—banyak orang menggunakan sepeda untuk pergi ke kantor atau pulang kerja. Sebaliknya, penggunaan sepeda paling rendah terjadi pada dini hari (00.00 - 05.00), yang kemungkinan karena aktivitas luar rumah sangat minim pada jam tersebut.

# %%
hours_df.to_csv("all_data.csv", index=False)
